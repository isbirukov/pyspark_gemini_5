# %% [markdown]
# ### The Shuffle
# - Создайте DataFrame из 1 млн чисел.
# - Сделайте repartition(2).
# - Сделайте count().
#
# Задание: Найдите в Spark UI блок "Exchange".
# Сделайте скриншот (или опишите), сколько задач (Tasks) было в каждом Stage.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .appName("Shuffle") \
        .master("local[*]") \
        .getOrCreate()

df = spark.range(0, 1000000)
df.count()
# Out:
# 1000000

# %%
spark.stop()

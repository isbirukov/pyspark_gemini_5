# %% [markdown]
# ## Создать, убедиться, что версия Spark — 3.5.0.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .appName("BIG_DATA_101_TEST") \
        .master("local[*]") \
        .getOrCreate()

print(spark.version)
spark.stop()
# Out:
# 3.5.0

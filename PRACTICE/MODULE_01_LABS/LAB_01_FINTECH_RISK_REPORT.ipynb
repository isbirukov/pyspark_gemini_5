# %% [markdown]
# ## Создать сессию, вывести версию.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .appName("FINTECH_RISK_REPORT") \
        .master("local[*]") \
        .getOrCreate()

print(f"Версия Spark: {spark.version}")
spark.stop()
# Out:
# Версия Spark: 3.5.0

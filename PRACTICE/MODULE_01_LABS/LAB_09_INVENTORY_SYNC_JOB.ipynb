# %% [markdown]
# ## Создать, распечатать URL мастера и имя.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .appName("INVENTORY_SYNC_JOB") \
        .master("local[*]") \
        .getOrCreate()

print(spark.sparkContext.appName)
print(spark.sparkContext.master)
spark.stop()
# Out:
# INVENTORY_SYNC_JOB
# local[*]

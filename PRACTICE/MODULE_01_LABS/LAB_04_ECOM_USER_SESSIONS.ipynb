# %% [markdown]
# ## Создать, вывести sc.master, остановить.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .appName("ECOM_USER_SESSIONS") \
        .master("local[*]") \
        .getOrCreate()

print(spark.sparkContext.master)
spark.stop()
# Out:
# local[*]

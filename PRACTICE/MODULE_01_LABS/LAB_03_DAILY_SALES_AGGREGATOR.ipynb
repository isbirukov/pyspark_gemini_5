# %% [markdown]
# ## Создать сессию, затем остановить.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .appName("DAILY_SALES_AGGREGATOR") \
        .master("local[*]") \
        .getOrCreate()

spark.stop()
